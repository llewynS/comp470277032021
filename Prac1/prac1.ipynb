# %% [markdown]
# # Machine Learning
# ## Practical 1
# Today we're going to set up our python environment and look at using pandas to make draftsman plots
#
# GOTO: https://github.com/llewynS/comp470277032021

# %%
# %matplotlib qt

# %%
import pandas as pd

# %%
df = pd.read_csv('mystery.csv')

# %%
df = df.drop(columns=['X1'])

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<AxesSubplot:xlabel='X2', ylabel='X2'>,
#         <AxesSubplot:xlabel='X3', ylabel='X2'>,
#         <AxesSubplot:xlabel='X4', ylabel='X2'>,
#         <AxesSubplot:xlabel='X5', ylabel='X2'>,
#         <AxesSubplot:xlabel='X6', ylabel='X2'>,
#         <AxesSubplot:xlabel='X7', ylabel='X2'>,
#         <AxesSubplot:xlabel='X8', ylabel='X2'>,
#         <AxesSubplot:xlabel='X9', ylabel='X2'>,
#         <AxesSubplot:xlabel='X10', ylabel='X2'>,
#         <AxesSubplot:xlabel='X11', ylabel='X2'>,
#         <AxesSubplot:xlabel='X12', ylabel='X2'>,
#         <AxesSubplot:xlabel='X13', ylabel='X2'>,
#         <AxesSubplot:xlabel='X14', ylabel='X2'>,
#         <AxesSubplot:xlabel='X15', ylabel='X2'>,
#         <AxesSubplot:xlabel='X16', ylabel='X2'>,
#         <AxesSubplot:xlabel='X17', ylabel='X2'>,
#         <AxesSubplot:xlabel='X18', ylabel='X2'>,
#         <AxesSubplot:xlabel='X19', ylabel='X2'>,
#         <AxesSubplot:xlabel='X20', ylabel='X2'>,
# ...

# %%
df2 = pd.read_csv('prac1_q3.dat', header=None)
df2
# Out:
#               0
# 0      2.107838
# 1     14.421908
# 2    -24.459045
# 3      5.190646
# 4      0.028270
# ...         ...
# 9995   5.148080
# 9996   2.184019
# 9997  14.610642
# 9998   6.462918
# 9999  -2.022532
#
# [10000 rows x 1 columns]

# %%
df2.mean()
# Out:
# 0   -2.984235
# dtype: float64

# %%
df2.std()
# Out:
# 0    9.419038
# dtype: float64

# %%
df2 = pd.read_csv('prac1_q4.dat', header=None, delimiter='\s+', engine='python')
df2
# Out:
#         0         1         2         3
# 0   -10.0 -3.000000 -8.396276 -1.183832
# 1    -9.9 -2.990752 -1.723503 -0.010239
# 2    -9.8 -2.963065 -6.383100 -0.520145
# 3    -9.7 -2.917110  9.912624  1.948031
# 4    -9.6 -2.853169  0.407724  0.000136
# ..    ...       ...       ...       ...
# 196   9.6  2.853169 -2.891809 -0.048366
# 197   9.7  2.917110  1.492989  0.006656
# 198   9.8  2.963065 -0.801095 -0.001028
# 199   9.9  2.990752  6.674496  0.594683
# 200  10.0  3.000000  6.308880  0.502212
#
# [201 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df2[0],df2[1],'bo')
plt.plot(df2[2],df2[3],'rs')

# %%
import numpy as np

# %%
a = np.random.normal(2,4,1000)

# %%
plt.hist(a,bins=30)
# Out:
# (array([ 2.,  3.,  4.,  5.,  2., 12., 18., 32., 40., 52., 61., 60., 86.,
#         91., 82., 85., 55., 61., 71., 62., 39., 24., 19., 13., 10.,  5.,
#          3.,  0.,  2.,  1.]),
#  array([-10.43797869,  -9.56977787,  -8.70157705,  -7.83337623,
#          -6.96517541,  -6.09697459,  -5.22877377,  -4.36057295,
#          -3.49237213,  -2.62417131,  -1.75597049,  -0.88776968,
#          -0.01956886,   0.84863196,   1.71683278,   2.5850336 ,
#           3.45323442,   4.32143524,   5.18963606,   6.05783688,
#           6.9260377 ,   7.79423852,   8.66243934,   9.53064016,
#          10.39884098,  11.2670418 ,  12.13524262,  13.00344344,
#          13.87164426,  14.73984508,  15.6080459 ]),
#  <BarContainer object of 30 artists>)
